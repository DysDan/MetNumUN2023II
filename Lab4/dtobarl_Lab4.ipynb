# %% [markdown]
# <a href="https://colab.research.google.com/github/dtobarl/MetNumUN2023II/blob/main/dtobarl_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tobar Lozano, Daniel Esteban - dtobarl@unal.edu.co
#
# #**ID** = 8

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x-8)(x+15)(x+16)(x+17)(x+18)(x+19)(x-20)(x-21)(x+22)(x+23)(x-24)(x-25)(x-26)(x+27)(x-28) = x^15 + 5 x^14 - 3369 x^13 - 23279 x^12 + 4734785 x^11 + 41389395 x^10 - 3564879667 x^9 - 37417392317 x^8 + 1528023234642 x^7 + 18666145933460 x^6 - 361336053383864 x^5 - 5072674004387904 x^4 + 40450635781875072 x^3 + 665475006180464640 x^2 - 1222253008336281600 x - 27978373094031360000

# %% [markdown]
# ![imagen_2023-09-13_092712794.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-09-13_092644836.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-09-13_092745472.png](data:image/png;base64,...)

# %% [markdown]
# expand[[(x-8)(x+15)(x+16)(x+17)(x+18)(x+19)(x-20)(x-21)(x+22)(x+23)(x-24)(x-25)(x-26)(x+27)(x-28)]/(x-1)]
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p= x**15 + 5*x**14 - 3369*x**13 - 23279*x**12 + 4734785*x**11 + 41389395*x**10 - 3564879667*x**9 - 37417392317*x**8 + 1528023234642*x**7 + 18666145933460*x**6 - 361336053383864*x**5 - 5072674004387904*x**4 + 40450635781875072*x**3 + 665475006180464640*x**2 - 1222253008336281600*x - 27978373094031360000

#(x-8)(x+15)(x+16)(x+17)(x+18)(x+19)(x-20)(x-21)(x+22)(x+23)(x-24)(x-25)(x-26)(x+27)(x-28)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-8)
print(p)
print(r)

p, r = div(p,  x+15)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+16)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+17)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+18)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+19)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-20)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-21)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+22)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+23)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-24)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-25)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-26)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x+27)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")
p, r = div(p, x-28)
print(p)
print(r)

print("-------------------------------------------------------------------------------------------------")

print("Prueba con una raíz que no es solución de polinomio ")
p, r = div(p, x-29)
print(p)
print(r)
# Out:
# -------------------------------------------------------------------------------------------------
# x**14 + 13*x**13 - 3265*x**12 - 49399*x**11 + 4339593*x**10 + 76106139*x**9 - 2956030555*x**8 - 61065636757*x**7 + 1039498140586*x**6 + 26982131058148*x**5 - 145479004918680*x**4 - 6236506043737344*x**3 - 9441412568023680*x**2 + 589943705636275200*x + 3497296636753920000
# 0
# x**13 - 2*x**12 - 3235*x**11 - 874*x**10 + 4352703*x**9 + 10815594*x**8 - 3118264465*x**7 - 14291669782*x**6 + 1253873187316*x**5 + 8174033248408*x**4 - 268089503644800*x**3 - 2215163489065344*x**2 + 23786039767956480*x + 233153109116928000
# 0
# -------------------------------------------------------------------------------------------------
# x**12 - 18*x**11 - 2947*x**10 + 46278*x**9 + 3612255*x**8 - 46980486*x**7 - 2366576689*x**6 + 23573557242*x**5 + 876696271444*x**4 - 5853107094696*x**3 - 174439790129664*x**2 + 575873153009280*x + 14572069319808000
# 0
# ...

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
#
# - factor(x\*\*15 + 5\*x\*\*14 - 3369\*x\*\*13 - 23279\*x\*\*12 + 4734785\*x\*\*11 + 41389395\*x\*\*10 - 3564879667\*x\*\*9 - 37417392317\*x\*\*8 + 1528023234642\*x\*\*7 + 18666145933460\*x\*\*6 - 361336053383864\*x\*\*5 - 5072674004387904\*x\*\*4 + 40450635781875072\*x\*\*3 + 665475006180464640\*x\*\*2 - 1222253008336281600\*x - 27978373094031360000)
#
# Como el polinomio es tan grande al escribirlo expandido Wolfram aplha no deja ejecutarlo por exceder el límite de caracteres.

# %% [markdown]
# ![imagen_2023-09-13_094651952.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**15 + 5*x**14 - 3369*x**13 - 23279*x**12 + 4734785*x**11 + 41389395*x**10 - 3564879667*x**9 - 37417392317*x**8
       + 1528023234642*x**7 + 18666145933460*x**6 - 361336053383864*x**5 - 5072674004387904*x**4
       + 40450635781875072*x**3 + 665475006180464640*x**2 - 1222253008336281600*x - 27978373094031360000)
# Out:
# (x - 28)*(x - 26)*(x - 25)*(x - 24)*(x - 21)*(x - 20)*(x - 8)*(x + 15)*(x + 16)*(x + 17)*(x + 18)*(x + 19)*(x + 22)*(x + 23)*(x + 27)

# %% [markdown]
# ## SymPy’s solvers
# - x\*\*15 + 5\*x\*\*14 - 3369\*x\*\*13 - 23279\*x\*\*12 + 4734785\*x\*\*11 + 41389395\*x\*\*10 - 3564879667\*x\*\*9 - 37417392317\*x\*\*8 + 1528023234642\*x\*\*7 + 18666145933460\*x\*\*6 - 361336053383864\*x\*\*5 - 5072674004387904\*x\*\*4 + 40450635781875072\*x\*\*3 + 665475006180464640\*x\*\*2 - 1222253008336281600\*x - 279783730940313600000=0

# %% [markdown]
# ![imagen_2023-09-13_095013032.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-09-13_095112330.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**15 + 5*x**14 - 3369*x**13 - 23279*x**12 + 4734785*x**11 + 41389395*x**10 - 3564879667*x**9 - 37417392317*x**8
       + 1528023234642*x**7 + 18666145933460*x**6 - 361336053383864*x**5 - 5072674004387904*x**4
       + 40450635781875072*x**3 + 665475006180464640*x**2 - 1222253008336281600*x - 27978373094031360000, 0), x)
# Out:
# {-27, -23, -22, -19, -18, -17, -16, -15, 8, 20, 21, 24, 25, 26, 28}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(((20*x**10)*(sqrt(3)-pi))-((25*x**8)*(sqrt(2)-E))+((26*pi*sqrt(3))*x**5)-(3*x**3)*(pi+E)+(pi*x)-32 , 0), x)
# Out:
# ConditionSet(x, Eq(20*x**10*(-pi + sqrt(3)) - 25*x**8*(-E + sqrt(2)) + 26*sqrt(3)*pi*x**5 - 3*x**3*(E + pi) + pi*x - 32, 0), Complexes)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![imagen_2023-09-13_095606129.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**15 + 5*x**14 - 3369*x**13 - 23279*x**12 + 4734785*x**11 + 41389395*x**10 - 3564879667*x**9 - 37417392317*x**8
       + 1528023234642*x**7 + 18666145933460*x**6 - 361336053383864*x**5 - 5072674004387904*x**4
       + 40450635781875072*x**3 + 665475006180464640*x**2 - 1222253008336281600*x - 27978373094031360000,domain='GF(3)')
# Out:
# x**5*(x - 1)**4*(x + 1)**6

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = 3*x1 + I*x2
y = 2*y1 + I*y2
z = z1 + I*z2

print(x*y*5*z)
print(expand(x*y*5*z))
print(expand((x*y)*5*z))
print(expand(x*(y*5*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# 5*(3*x1 + I*x2)*(2*y1 + I*y2)*(z1 + I*z2)
# 30*x1*y1*z1 + 30*I*x1*y1*z2 + 15*I*x1*y2*z1 - 15*x1*y2*z2 + 10*I*x2*y1*z1 - 10*x2*y1*z2 - 5*x2*y2*z1 - 5*I*x2*y2*z2
# 30*x1*y1*z1 + 30*I*x1*y1*z2 + 15*I*x1*y2*z1 - 15*x1*y2*z2 + 10*I*x2*y1*z1 - 10*x2*y1*z2 - 5*x2*y2*z1 - 5*I*x2*y2*z2
# 30*x1*y1*z1 + 30*I*x1*y1*z2 + 15*I*x1*y2*z1 - 15*x1*y2*z2 + 10*I*x2*y1*z1 - 10*x2*y1*z2 - 5*x2*y2*z1 - 5*I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram8.jpg" />

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-09-06_185439920.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-09-06_185726034.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**5 * cos(x)**2, x)
# Out:
# x**6*sin(x)**2/12 + x**6*cos(x)**2/12 + x**5*sin(x)*cos(x)/2 - 5*x**4*sin(x)**2/8 + 5*x**4*cos(x)**2/8 - 5*x**3*sin(x)*cos(x)/2 + 15*x**2*sin(x)**2/8 - 15*x**2*cos(x)**2/8 + 15*x*sin(x)*cos(x)/4 + 15*cos(x)**2/8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**5 * cos(x)**2, (x,3,10))
# Out:
# -771*cos(3)**2/8 - 27*sin(3)**2 - 261*sin(3)*cos(3)/4 + 95075*sin(10)*cos(10)/2 + 463625*sin(10)**2/6 + 2145545*cos(10)**2/24

# %%
from sympy import Symbol, integrate, cos,N
x = Symbol('x')
N(integrate(x**5 * cos(x)**2, (x,3,10)))
# Out:
# 107422.340862053
